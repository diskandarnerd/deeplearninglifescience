# %% [markdown]
# <a href="https://colab.research.google.com/github/diskandarnerd/deeplearninglifescience/blob/master/graphconvolution_deepchem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !time bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -y -c deepchem -c rdkit -c conda-forge -c omnia deepchem-gpu=2.1.0 python=3.6
# Out:
# --2019-10-04 14:03:43--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75257002 (72M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  71.77M   114MB/s    in 0.6s
#
# 2019-10-04 14:03:49 (114 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [75257002/75257002]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==0.24.0=py37_0
#     - bzip2==1.0.8=h7b6447c_0
#     - ca-certificates==2019.5.15=0
#     - certifi==2019.6.16=py37_0
#     - cffi==1.12.3=py37h2e261b9_0
#     - chardet==3.0.4=py37_1
#     - conda-package-handling==1.3.11=py37_0
#     - conda==4.7.10=py37_0
#     - cryptography==2.7=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - libarchive==3.3.3=h5d8350f_5
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - libxml2==2.9.9=hea5a465_1
#     - lz4-c==1.8.1.2=h14c3975_0
#     - lzo==2.10=h49e0be7_2
#     - ncurses==6.1=he6710b0_1
#     - openssl==1.1.1c=h7b6447c_1
#     - pip==19.1.1=py37_0
#     - pycosat==0.6.3=py37h14c3975_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.0.0=py37_0
#     - pysocks==1.7.0=py37_0
#     - python-libarchive-c==2.8=py37_11
#     - python==3.7.3=h0371630_0
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_0
#     - ruamel_yaml==0.15.46=py37h14c3975_0
#     - setuptools==41.0.1=py37_0
#     - six==1.12.0=py37_0
#     - sqlite==3.29.0=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.32.1=py_0
#     - urllib3==1.24.2=py37_0
#     - wheel==0.33.4=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#     - zstd==1.3.7=h0b5b093_0
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-0.24.0-py37_0
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2019.5.15-0
#   certifi            pkgs/main/linux-64::certifi-2019.6.16-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.12.3-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1
#   conda              pkgs/main/linux-64::conda-4.7.10-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.3.11-py37_0
#   cryptography       pkgs/main/linux-64::cryptography-2.7-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   libarchive         pkgs/main/linux-64::libarchive-3.3.3-h5d8350f_5
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.9-hea5a465_1
#   lz4-c              pkgs/main/linux-64::lz4-c-1.8.1.2-h14c3975_0
#   lzo                pkgs/main/linux-64::lzo-2.10-h49e0be7_2
#   ncurses            pkgs/main/linux-64::ncurses-6.1-he6710b0_1
#   openssl            pkgs/main/linux-64::openssl-1.1.1c-h7b6447c_1
#   pip                pkgs/main/linux-64::pip-19.1.1-py37_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h14c3975_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.0.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.0-py37_0
#   python             pkgs/main/linux-64::python-3.7.3-h0371630_0
#   python-libarchive~ pkgs/main/linux-64::python-libarchive-c-2.8-py37_11
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.46-py37h14c3975_0
#   setuptools         pkgs/main/linux-64::setuptools-41.0.1-py37_0
#   six                pkgs/main/linux-64::six-1.12.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.29.0-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.32.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.24.2-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.33.4-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#   zstd               pkgs/main/linux-64::zstd-1.3.7-h0b5b093_0
#
#
# done
# | WARNING conda.core.envs_manager:register_env(46): Unable to register environment. Path not writable or missing.
#   environment location: /usr/local
#   registry file: /root/.conda/environments.txt
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
#
# real	0m18.695s
# user	0m9.947s
# sys	0m4.773s
# done
# failed with current_repodata.json, will retry with next repodata source.
# Initial quick solve with frozen env failed.  Unfreezing env and trying again.
# failed with current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - deepchem-gpu=2.1.0
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-0.8.0              |           py36_0         157 KB  conda-forge
#     asn1crypto-1.0.0           |           py36_0         157 KB  conda-forge
#     astor-0.7.1                |             py_0          22 KB  conda-forge
#     attrs-19.2.0               |             py_0          35 KB  conda-forge
#     backcall-0.1.0             |             py_0          13 KB  conda-forge
#     blas-1.0                   |              mkl           6 KB
#     bleach-1.5.0               |           py36_0          23 KB  conda-forge
#     blosc-1.17.0               |       he1b5a44_1         862 KB  conda-forge
#     boost-1.63.0               |   py36h415b752_1        11.8 MB  rdkit
#     c-ares-1.15.0              |    h516909a_1001         100 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     cairo-1.14.12              |       he56eebe_3         1.3 MB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     cffi-1.12.3                |   py36h8022711_0         218 KB  conda-forge
#     chardet-3.0.4              |        py36_1003         190 KB  conda-forge
#     conda-4.7.12               |           py36_0         3.0 MB  conda-forge
#     conda-package-handling-1.6.0|   py36h516909a_0         926 KB  conda-forge
#     cryptography-2.5           |   py36hb7f436b_1         645 KB  conda-forge
#     cudatoolkit-9.0            |       h13b8566_0       237.0 MB
#     cudnn-7.6.0                |        cuda9.0_0       136.6 MB
#     cupti-9.0.176              |                0         1.4 MB
#     cycler-0.10.0              |             py_1           8 KB  conda-forge
#     cython-0.29.13             |   py36he1b5a44_0         2.2 MB  conda-forge
#     dbus-1.13.0                |    h4e0c4b3_1000         558 KB  conda-forge
#     decorator-4.4.0            |             py_0          11 KB  conda-forge
#     deepchem-gpu-2.1.0         |           py36_0         1.9 MB  deepchem
#     defusedxml-0.6.0           |             py_0          22 KB  conda-forge
#     entrypoints-0.3            |        py36_1000          12 KB  conda-forge
#     expat-2.2.5                |    he1b5a44_1003         191 KB  conda-forge
#     fftw3f-3.3.4               |                2         1.2 MB  omnia
#     fontconfig-2.13.0          |       hd36ec8e_5         284 KB  conda-forge
#     freetype-2.8.1             |       hfa320df_1         789 KB  conda-forge
#     gast-0.3.2                 |             py_0          11 KB  conda-forge
#     gettext-0.19.8.1           |    hc5be6a0_1002         3.6 MB  conda-forge
#     glib-2.55.0                |       h464dc38_2         6.1 MB  conda-forge
#     grpcio-1.16.0              |py36h4f00d22_1000         1.0 MB  conda-forge
#     gst-plugins-base-1.12.5    |    h3865690_1000         4.9 MB  conda-forge
#     gstreamer-1.12.5           |       h61a6719_0         2.1 MB  conda-forge
#     hdf5-1.10.5                |nompi_h3c11f04_1103         3.1 MB  conda-forge
#     html5lib-0.9999999         |           py36_0         181 KB  conda-forge
#     icu-58.2                   |    hf484d3e_1000        22.6 MB  conda-forge
#     idna-2.6                   |           py36_1         122 KB  conda-forge
#     intel-openmp-2019.4        |              243         729 KB
#     ipykernel-5.1.2            |   py36h5ca1d4c_0         159 KB  conda-forge
#     ipython-7.8.0              |   py36h5ca1d4c_0         1.1 MB  conda-forge
#     ipython_genutils-0.2.0     |             py_1          21 KB  conda-forge
#     ipywidgets-7.5.1           |             py_0         101 KB  conda-forge
#     jedi-0.15.1                |           py36_0         717 KB  conda-forge
#     jinja2-2.10.1              |             py_0          91 KB  conda-forge
#     joblib-0.11                |           py36_0         193 KB  conda-forge
#     jpeg-9c                    |    h14c3975_1001         251 KB  conda-forge
#     jsonschema-3.0.2           |           py36_0          87 KB  conda-forge
#     jupyter-1.0.0              |             py_2           4 KB  conda-forge
#     jupyter_client-5.3.3       |           py36_1         132 KB  conda-forge
#     jupyter_console-6.0.0      |             py_0          19 KB  conda-forge
#     jupyter_core-4.4.0         |             py_0          44 KB  conda-forge
#     kiwisolver-1.1.0           |   py36hc9558a2_0          86 KB  conda-forge
#     libgfortran-ng-7.3.0       |       hdf63c60_0        1006 KB
#     libiconv-1.15              |    h516909a_1005         2.0 MB  conda-forge
#     libpng-1.6.37              |       hed695b0_0         343 KB  conda-forge
#     libprotobuf-3.9.2          |       h8b12597_0         4.7 MB  conda-forge
#     libsodium-1.0.17           |       h516909a_0         330 KB  conda-forge
#     libtiff-4.0.9              |    h648cc4a_1002         566 KB  conda-forge
#     libuuid-2.32.1             |    h14c3975_1000          26 KB  conda-forge
#     libxcb-1.13                |    h14c3975_1002         396 KB  conda-forge
#     markdown-3.1.1             |             py_0          60 KB  conda-forge
#     markupsafe-1.1.1           |   py36h14c3975_0          26 KB  conda-forge
#     matplotlib-2.2.2           |   py36h0e671d2_0         4.8 MB
#     mdtraj-1.9.1               |           py36_1         5.9 MB  deepchem
#     mistune-0.8.4              |py36h14c3975_1000          53 KB  conda-forge
#     mkl-2018.0.3               |                1       126.9 MB
#     mkl_fft-1.0.10             |           py36_0         650 KB  conda-forge
#     mkl_random-1.0.2           |           py36_0         1.3 MB  conda-forge
#     mock-3.0.5                 |           py36_0          44 KB  conda-forge
#     nbconvert-5.6.0            |           py36_1         465 KB  conda-forge
#     nbformat-4.4.0             |             py_1          91 KB  conda-forge
#     networkx-2.1               |             py_1         1.1 MB  conda-forge
#     notebook-6.0.1             |           py36_0         6.0 MB  conda-forge
#     numexpr-2.7.0              |   py36hb3f55d8_0         196 KB  conda-forge
#     numpy-1.15.4               |   py36h1d66e8a_0          34 KB
#     numpy-base-1.15.4          |   py36h81de0dd_0         3.4 MB
#     olefile-0.46               |             py_0          31 KB  conda-forge
#     openmm-7.4.0               |py36_cuda101_rc_1        11.9 MB  omnia
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     pandas-0.22.0              |           py36_1        26.1 MB  conda-forge
#     pandoc-2.7.3               |                0        22.4 MB  conda-forge
#     pandocfilters-1.4.2        |             py_1           9 KB  conda-forge
#     parso-0.5.1                |             py_0          65 KB  conda-forge
#     pcre-8.41                  |    hf484d3e_1003         249 KB  conda-forge
#     pdbfixer-1.4               |           py36_0         187 KB  omnia
#     pexpect-4.7.0              |           py36_0          78 KB  conda-forge
#     pickleshare-0.7.5          |        py36_1000          12 KB  conda-forge
#     pillow-5.0.0               |           py36_0         975 KB  conda-forge
#     pip-19.2.3                 |           py36_0         1.9 MB  conda-forge
#     pixman-0.34.0              |    h14c3975_1003         595 KB  conda-forge
#     prometheus_client-0.7.1    |             py_0          38 KB  conda-forge
#     prompt_toolkit-2.0.10      |             py_0         221 KB  conda-forge
#     protobuf-3.9.2             |   py36he1b5a44_1         686 KB  conda-forge
#     pthread-stubs-0.4          |    h14c3975_1001           5 KB  conda-forge
#     ptyprocess-0.6.0           |          py_1001          15 KB  conda-forge
#     pycosat-0.6.3              |py36h14c3975_1001         104 KB  conda-forge
#     pycparser-2.19             |           py36_1         173 KB  conda-forge
#     pygments-2.4.2             |             py_0         661 KB  conda-forge
#     pyopenssl-19.0.0           |           py36_0          81 KB  conda-forge
#     pyparsing-2.4.2            |             py_0          57 KB  conda-forge
#     pyqt-5.6.0                 |py36h13b7fb3_1008         5.4 MB  conda-forge
#     pyrsistent-0.15.4          |   py36h516909a_0          89 KB  conda-forge
#     pysocks-1.7.1              |           py36_0          27 KB  conda-forge
#     pytables-3.5.2             |   py36h9f153d1_2         1.5 MB  conda-forge
#     python-3.6.6               |    hd21baee_1003        29.0 MB  conda-forge
#     python-dateutil-2.8.0      |             py_0         219 KB  conda-forge
#     pytz-2019.2                |             py_0         228 KB  conda-forge
#     pyzmq-18.1.0               |   py36h1768529_0         516 KB  conda-forge
#     qt-5.6.2                   |      h974d657_12        34.8 MB
#     qtconsole-4.5.5            |             py_0          90 KB  conda-forge
#     rdkit-2017.09.1            |           py36_1        19.7 MB  rdkit
#     requests-2.18.4            |           py36_1          91 KB  conda-forge
#     ruamel_yaml-0.15.71        |py36h14c3975_1000         257 KB  conda-forge
#     scikit-learn-0.19.1        |   py36hedc7406_0         3.9 MB
#     scipy-1.1.0                |   py36hfa4b5c9_1        13.2 MB
#     send2trash-1.5.0           |             py_0          12 KB  conda-forge
#     setuptools-41.2.0          |           py36_0         634 KB  conda-forge
#     simdna-0.4.2               |             py_0         627 KB  deepchem
#     sip-4.18.1                 |py36hf484d3e_1000         277 KB  conda-forge
#     six-1.12.0                 |        py36_1000          22 KB  conda-forge
#     tensorboard-1.6.0          |           py36_0         2.9 MB  conda-forge
#     tensorflow-gpu-1.6.0       |                0           4 KB
#     tensorflow-gpu-base-1.6.0  |   py36hcdda91b_1        68.1 MB
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     terminado-0.8.2            |           py36_0          23 KB  conda-forge
#     testpath-0.4.2             |          py_1001          85 KB  conda-forge
#     tornado-6.0.3              |   py36h516909a_0         636 KB  conda-forge
#     traitlets-4.3.3            |           py36_0         133 KB  conda-forge
#     urllib3-1.22               |           py36_0         154 KB  conda-forge
#     wcwidth-0.1.7              |             py_1          17 KB  conda-forge
#     webencodings-0.5.1         |             py_1          12 KB  conda-forge
#     werkzeug-0.16.0            |             py_0         259 KB  conda-forge
#     wheel-0.33.6               |           py36_0          35 KB  conda-forge
#     widgetsnbextension-3.5.1   |           py36_0         1.8 MB  conda-forge
#     xgboost-0.6a2              |           py36_2         1.1 MB  conda-forge
#     xorg-kbproto-1.0.7         |    h14c3975_1002          26 KB  conda-forge
#     xorg-libice-1.0.10         |       h516909a_0          57 KB  conda-forge
#     xorg-libsm-1.2.3           |    h84519dc_1000          25 KB  conda-forge
#     xorg-libx11-1.6.8          |       h516909a_0         907 KB  conda-forge
#     xorg-libxau-1.0.9          |       h14c3975_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h516909a_0          18 KB  conda-forge
#     xorg-libxext-1.3.4         |       h516909a_0          51 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h516909a_1002          31 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h14c3975_1002           8 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h14c3975_1002          27 KB  conda-forge
#     xorg-xproto-7.0.31         |    h14c3975_1007          72 KB  conda-forge
#     zeromq-4.3.2               |       he1b5a44_2         668 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       866.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   absl-py            conda-forge/linux-64::absl-py-0.8.0-py36_0
#   astor              conda-forge/noarch::astor-0.7.1-py_0
#   attrs              conda-forge/noarch::attrs-19.2.0-py_0
#   backcall           conda-forge/noarch::backcall-0.1.0-py_0
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bleach             conda-forge/linux-64::bleach-1.5.0-py36_0
#   blosc              conda-forge/linux-64::blosc-1.17.0-he1b5a44_1
#   boost              rdkit/linux-64::boost-1.63.0-py36h415b752_1
#   c-ares             conda-forge/linux-64::c-ares-1.15.0-h516909a_1001
#   cairo              conda-forge/linux-64::cairo-1.14.12-he56eebe_3
#   cudatoolkit        pkgs/main/linux-64::cudatoolkit-9.0-h13b8566_0
#   cudnn              pkgs/main/linux-64::cudnn-7.6.0-cuda9.0_0
#   cupti              pkgs/main/linux-64::cupti-9.0.176-0
#   cycler             conda-forge/noarch::cycler-0.10.0-py_1
#   cython             conda-forge/linux-64::cython-0.29.13-py36he1b5a44_0
#   dbus               conda-forge/linux-64::dbus-1.13.0-h4e0c4b3_1000
#   decorator          conda-forge/noarch::decorator-4.4.0-py_0
#   deepchem-gpu       deepchem/linux-64::deepchem-gpu-2.1.0-py36_0
#   defusedxml         conda-forge/noarch::defusedxml-0.6.0-py_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36_1000
#   expat              conda-forge/linux-64::expat-2.2.5-he1b5a44_1003
#   fftw3f             omnia/linux-64::fftw3f-3.3.4-2
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.0-hd36ec8e_5
#   freetype           conda-forge/linux-64::freetype-2.8.1-hfa320df_1
#   gast               conda-forge/noarch::gast-0.3.2-py_0
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-hc5be6a0_1002
#   glib               conda-forge/linux-64::glib-2.55.0-h464dc38_2
#   grpcio             conda-forge/linux-64::grpcio-1.16.0-py36h4f00d22_1000
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.12.5-h3865690_1000
#   gstreamer          conda-forge/linux-64::gstreamer-1.12.5-h61a6719_0
#   hdf5               conda-forge/linux-64::hdf5-1.10.5-nompi_h3c11f04_1103
#   html5lib           conda-forge/linux-64::html5lib-0.9999999-py36_0
#   icu                conda-forge/linux-64::icu-58.2-hf484d3e_1000
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2019.4-243
#   ipykernel          conda-forge/linux-64::ipykernel-5.1.2-py36h5ca1d4c_0
#   ipython            conda-forge/linux-64::ipython-7.8.0-py36h5ca1d4c_0
#   ipython_genutils   conda-forge/noarch::ipython_genutils-0.2.0-py_1
#   ipywidgets         conda-forge/noarch::ipywidgets-7.5.1-py_0
#   jedi               conda-forge/linux-64::jedi-0.15.1-py36_0
#   jinja2             conda-forge/noarch::jinja2-2.10.1-py_0
#   joblib             conda-forge/linux-64::joblib-0.11-py36_0
#   jpeg               conda-forge/linux-64::jpeg-9c-h14c3975_1001
#   jsonschema         conda-forge/linux-64::jsonschema-3.0.2-py36_0
#   jupyter            conda-forge/noarch::jupyter-1.0.0-py_2
#   jupyter_client     conda-forge/linux-64::jupyter_client-5.3.3-py36_1
#   jupyter_console    conda-forge/noarch::jupyter_console-6.0.0-py_0
#   jupyter_core       conda-forge/noarch::jupyter_core-4.4.0-py_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.1.0-py36hc9558a2_0
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.3.0-hdf63c60_0
#   libiconv           conda-forge/linux-64::libiconv-1.15-h516909a_1005
#   libpng             conda-forge/linux-64::libpng-1.6.37-hed695b0_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.9.2-h8b12597_0
#   libsodium          conda-forge/linux-64::libsodium-1.0.17-h516909a_0
#   libtiff            conda-forge/linux-64::libtiff-4.0.9-h648cc4a_1002
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h14c3975_1000
#   libxcb             conda-forge/linux-64::libxcb-1.13-h14c3975_1002
#   markdown           conda-forge/noarch::markdown-3.1.1-py_0
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h14c3975_0
#   matplotlib         pkgs/main/linux-64::matplotlib-2.2.2-py36h0e671d2_0
#   mdtraj             deepchem/linux-64::mdtraj-1.9.1-py36_1
#   mistune            conda-forge/linux-64::mistune-0.8.4-py36h14c3975_1000
#   mkl                pkgs/main/linux-64::mkl-2018.0.3-1
#   mkl_fft            conda-forge/linux-64::mkl_fft-1.0.10-py36_0
#   mkl_random         conda-forge/linux-64::mkl_random-1.0.2-py36_0
#   mock               conda-forge/linux-64::mock-3.0.5-py36_0
#   nbconvert          conda-forge/linux-64::nbconvert-5.6.0-py36_1
#   nbformat           conda-forge/noarch::nbformat-4.4.0-py_1
#   networkx           conda-forge/noarch::networkx-2.1-py_1
#   notebook           conda-forge/linux-64::notebook-6.0.1-py36_0
#   numexpr            conda-forge/linux-64::numexpr-2.7.0-py36hb3f55d8_0
#   numpy              pkgs/main/linux-64::numpy-1.15.4-py36h1d66e8a_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.15.4-py36h81de0dd_0
#   olefile            conda-forge/noarch::olefile-0.46-py_0
#   openmm             omnia/linux-64::openmm-7.4.0-py36_cuda101_rc_1
#   pandas             conda-forge/linux-64::pandas-0.22.0-py36_1
#   pandoc             conda-forge/linux-64::pandoc-2.7.3-0
#   pandocfilters      conda-forge/noarch::pandocfilters-1.4.2-py_1
#   parso              conda-forge/noarch::parso-0.5.1-py_0
#   pcre               conda-forge/linux-64::pcre-8.41-hf484d3e_1003
#   pdbfixer           omnia/linux-64::pdbfixer-1.4-py36_0
#   pexpect            conda-forge/linux-64::pexpect-4.7.0-py36_0
#   pickleshare        conda-forge/linux-64::pickleshare-0.7.5-py36_1000
#   pillow             conda-forge/linux-64::pillow-5.0.0-py36_0
#   pixman             conda-forge/linux-64::pixman-0.34.0-h14c3975_1003
#   prometheus_client  conda-forge/noarch::prometheus_client-0.7.1-py_0
#   prompt_toolkit     conda-forge/noarch::prompt_toolkit-2.0.10-py_0
#   protobuf           conda-forge/linux-64::protobuf-3.9.2-py36he1b5a44_1
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h14c3975_1001
#   ptyprocess         conda-forge/noarch::ptyprocess-0.6.0-py_1001
#   pygments           conda-forge/noarch::pygments-2.4.2-py_0
#   pyparsing          conda-forge/noarch::pyparsing-2.4.2-py_0
#   pyqt               conda-forge/linux-64::pyqt-5.6.0-py36h13b7fb3_1008
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.15.4-py36h516909a_0
#   pytables           conda-forge/linux-64::pytables-3.5.2-py36h9f153d1_2
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.0-py_0
#   pytz               conda-forge/noarch::pytz-2019.2-py_0
#   pyzmq              conda-forge/linux-64::pyzmq-18.1.0-py36h1768529_0
#   qt                 pkgs/main/linux-64::qt-5.6.2-h974d657_12
#   qtconsole          conda-forge/noarch::qtconsole-4.5.5-py_0
#   rdkit              rdkit/linux-64::rdkit-2017.09.1-py36_1
#   scikit-learn       pkgs/main/linux-64::scikit-learn-0.19.1-py36hedc7406_0
#   scipy              pkgs/main/linux-64::scipy-1.1.0-py36hfa4b5c9_1
#   send2trash         conda-forge/noarch::send2trash-1.5.0-py_0
#   simdna             deepchem/noarch::simdna-0.4.2-py_0
#   sip                conda-forge/linux-64::sip-4.18.1-py36hf484d3e_1000
#   tensorboard        conda-forge/linux-64::tensorboard-1.6.0-py36_0
#   tensorflow-gpu     pkgs/main/linux-64::tensorflow-gpu-1.6.0-0
#   tensorflow-gpu-ba~ pkgs/main/linux-64::tensorflow-gpu-base-1.6.0-py36hcdda91b_1
#   termcolor          conda-forge/noarch::termcolor-1.1.0-py_2
#   terminado          conda-forge/linux-64::terminado-0.8.2-py36_0
#   testpath           conda-forge/noarch::testpath-0.4.2-py_1001
#   tornado            conda-forge/linux-64::tornado-6.0.3-py36h516909a_0
#   traitlets          conda-forge/linux-64::traitlets-4.3.3-py36_0
#   wcwidth            conda-forge/noarch::wcwidth-0.1.7-py_1
#   webencodings       conda-forge/noarch::webencodings-0.5.1-py_1
#   werkzeug           conda-forge/noarch::werkzeug-0.16.0-py_0
#   widgetsnbextension conda-forge/linux-64::widgetsnbextension-3.5.1-py36_0
#   xgboost            conda-forge/linux-64::xgboost-0.6a2-py36_2
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h14c3975_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h516909a_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-h84519dc_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.6.8-h516909a_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h14c3975_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h516909a_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h516909a_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h516909a_1002
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h14c3975_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h14c3975_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h14c3975_1007
#   zeromq             conda-forge/linux-64::zeromq-4.3.2-he1b5a44_2
#
# The following packages will be REMOVED:
#
#   libarchive-3.3.3-h5d8350f_5
#   python-libarchive-c-2.8-py37_11
#
# The following packages will be UPDATED:
#
#   asn1crypto            pkgs/main::asn1crypto-0.24.0-py37_0 --> conda-forge::asn1crypto-1.0.0-py36_0
#   ca-certificates    pkgs/main::ca-certificates-2019.5.15-0 --> conda-forge::ca-certificates-2019.9.11-hecc5488_0
#   certifi               pkgs/main::certifi-2019.6.16-py37_0 --> conda-forge::certifi-2019.9.11-py36_0
#   chardet                   pkgs/main::chardet-3.0.4-py37_1 --> conda-forge::chardet-3.0.4-py36_1003
#   conda                      pkgs/main::conda-4.7.10-py37_0 --> conda-forge::conda-4.7.12-py36_0
#   conda-package-han~ pkgs/main::conda-package-handling-1.3~ --> conda-forge::conda-package-handling-1.6.0-py36h516909a_0
#   pip                          pkgs/main::pip-19.1.1-py37_0 --> conda-forge::pip-19.2.3-py36_0
#   pycosat            pkgs/main::pycosat-0.6.3-py37h14c3975~ --> conda-forge::pycosat-0.6.3-py36h14c3975_1001
#   pycparser                pkgs/main::pycparser-2.19-py37_0 --> conda-forge::pycparser-2.19-py36_1
#   pysocks                   pkgs/main::pysocks-1.7.0-py37_0 --> conda-forge::pysocks-1.7.1-py36_0
#   ruamel_yaml        pkgs/main::ruamel_yaml-0.15.46-py37h1~ --> conda-forge::ruamel_yaml-0.15.71-py36h14c3975_1000
#   setuptools            pkgs/main::setuptools-41.0.1-py37_0 --> conda-forge::setuptools-41.2.0-py36_0
#   six                          pkgs/main::six-1.12.0-py37_0 --> conda-forge::six-1.12.0-py36_1000
#   wheel                      pkgs/main::wheel-0.33.4-py37_0 --> conda-forge::wheel-0.33.6-py36_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   cffi                pkgs/main::cffi-1.12.3-py37h2e261b9_0 --> conda-forge::cffi-1.12.3-py36h8022711_0
#   cryptography       pkgs/main::cryptography-2.7-py37h1ba5~ --> conda-forge::cryptography-2.5-py36hb7f436b_1
#   idna                           pkgs/main::idna-2.8-py37_0 --> conda-forge::idna-2.6-py36_1
#   openssl              pkgs/main::openssl-1.1.1c-h7b6447c_1 --> conda-forge::openssl-1.0.2r-h14c3975_0
#   pyopenssl              pkgs/main::pyopenssl-19.0.0-py37_0 --> conda-forge::pyopenssl-19.0.0-py36_0
#   python                 pkgs/main::python-3.7.3-h0371630_0 --> conda-forge::python-3.6.6-hd21baee_1003
#   requests                pkgs/main::requests-2.22.0-py37_0 --> conda-forge::requests-2.18.4-py36_1
#   urllib3                  pkgs/main::urllib3-1.24.2-py37_0 --> conda-forge::urllib3-1.22-py36_0
#
#
#
# Downloading and Extracting Packages
# tornado-6.0.3        | 636 KB    | : 100% 1.0/1 [00:00<00:00,  4.30it/s]
# tensorflow-gpu-1.6.0 | 4 KB      | : 100% 1.0/1 [00:00<00:00,  6.75it/s]
# termcolor-1.1.0      | 6 KB      | : 100% 1.0/1 [00:00<00:00, 26.61it/s]
# markupsafe-1.1.1     | 26 KB     | : 100% 1.0/1 [00:00<00:00, 20.43it/s]
# tensorboard-1.6.0    | 2.9 MB    | : 100% 1.0/1 [00:00<00:00, 17.26s/it]
# pandoc-2.7.3         | 22.4 MB   | : 100% 1.0/1 [00:05<00:00,  5.18s/it]
# xorg-libsm-1.2.3     | 25 KB     | : 100% 1.0/1 [00:00<00:00, 22.08it/s]
# widgetsnbextension-3 | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# parso-0.5.1          | 65 KB     | : 100% 1.0/1 [00:00<00:00,  1.44it/s]
# pysocks-1.7.1        | 27 KB     | : 100% 1.0/1 [00:00<00:00, 28.58it/s]
# webencodings-0.5.1   | 12 KB     | : 100% 1.0/1 [00:00<00:00, 24.91it/s]
# pyrsistent-0.15.4    | 89 KB     | : 100% 1.0/1 [00:00<00:00, 17.81it/s]
# astor-0.7.1          | 22 KB     | : 100% 1.0/1 [00:00<00:00,  2.51it/s]
# six-1.12.0           | 22 KB     | : 100% 1.0/1 [00:00<00:00, 25.94it/s]
# networkx-2.1         | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.24it/s]
# python-3.6.6         | 29.0 MB   | : 100% 1.0/1 [00:04<00:00,  4.32s/it]
# urllib3-1.22         | 154 KB    | : 100% 1.0/1 [00:00<00:00, 12.71it/s]
# libgfortran-ng-7.3.0 | 1006 KB   | : 100% 1.0/1 [00:00<00:00,  7.86it/s]
# prompt_toolkit-2.0.1 | 221 KB    | : 100% 1.0/1 [00:00<00:00,  7.95it/s]
# cycler-0.10.0        | 8 KB      | : 100% 1.0/1 [00:00<00:00, 23.19it/s]
# intel-openmp-2019.4  | 729 KB    | : 100% 1.0/1 [00:00<00:00, 11.49it/s]
# xorg-libx11-1.6.8    | 907 KB    | : 100% 1.0/1 [00:00<00:00,  4.26it/s]
# protobuf-3.9.2       | 686 KB    | : 100% 1.0/1 [00:00<00:00,  4.44it/s]
# html5lib-0.9999999   | 181 KB    | : 100% 1.0/1 [00:00<00:00, 11.05it/s]
# grpcio-1.16.0        | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.43it/s]
# nbconvert-5.6.0      | 465 KB    | : 100% 1.0/1 [00:00<00:00,  6.78it/s]
# prometheus_client-0. | 38 KB     | : 100% 1.0/1 [00:00<00:00, 20.76it/s]
# xorg-libxrender-0.9. | 31 KB     | : 100% 1.0/1 [00:00<00:00, 26.00it/s]
# attrs-19.2.0         | 35 KB     | : 100% 1.0/1 [00:00<00:00, 26.07it/s]
# cython-0.29.13       | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.99it/s]
# jupyter-1.0.0        | 4 KB      | : 100% 1.0/1 [00:00<00:00, 23.33it/s]
# xorg-renderproto-0.1 | 8 KB      | : 100% 1.0/1 [00:00<00:00, 28.27it/s]
# cudnn-7.6.0          | 136.6 MB  | : 100% 1.0/1 [00:03<00:00,  3.95s/it]
# requests-2.18.4      | 91 KB     | : 100% 1.0/1 [00:00<00:00, 17.98it/s]
# jsonschema-3.0.2     | 87 KB     | : 100% 1.0/1 [00:00<00:00, 15.82it/s]
# libsodium-1.0.17     | 330 KB    | : 100% 1.0/1 [00:00<00:00, 10.42it/s]
# xorg-libxdmcp-1.1.3  | 18 KB     | : 100% 1.0/1 [00:00<00:00, 22.64it/s]
# ipywidgets-7.5.1     | 101 KB    | : 100% 1.0/1 [00:00<00:00, 14.78it/s]
# decorator-4.4.0      | 11 KB     | : 100% 1.0/1 [00:00<00:00, 28.92it/s]
# libpng-1.6.37        | 343 KB    | : 100% 1.0/1 [00:00<00:00,  9.68it/s]
# jedi-0.15.1          | 717 KB    | : 100% 1.0/1 [00:00<00:00,  2.97it/s]
# openssl-1.0.2r       | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.72it/s]
# gstreamer-1.12.5     | 2.1 MB    | : 100% 1.0/1 [00:00<00:00, 11.06s/it]
# xorg-libice-1.0.10   | 57 KB     | : 100% 1.0/1 [00:00<00:00, 25.32it/s]
# pygments-2.4.2       | 661 KB    | : 100% 1.0/1 [00:00<00:00,  5.25it/s]
# scipy-1.1.0          | 13.2 MB   | : 100% 1.0/1 [00:00<00:00,  2.08it/s]
# xorg-xextproto-7.3.0 | 27 KB     | : 100% 1.0/1 [00:00<00:00, 25.36it/s]
# xorg-xproto-7.0.31   | 72 KB     | : 100% 1.0/1 [00:00<00:00, 21.58it/s]
# dbus-1.13.0          | 558 KB    | : 100% 1.0/1 [00:00<00:00,  6.87it/s]
# pytables-3.5.2       | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.67it/s]
# olefile-0.46         | 31 KB     | : 100% 1.0/1 [00:00<00:00, 26.69it/s]
# mdtraj-1.9.1         | 5.9 MB    | : 100% 1.0/1 [00:02<00:00, 51.64s/it]
# conda-package-handli | 926 KB    | : 100% 1.0/1 [00:00<00:00,  5.94it/s]
# ca-certificates-2019 | 144 KB    | : 100% 1.0/1 [00:00<00:00, 12.72it/s]
# pcre-8.41            | 249 KB    | : 100% 1.0/1 [00:00<00:00, 11.49it/s]
# xorg-libxext-1.3.4   | 51 KB     | : 100% 1.0/1 [00:00<00:00, 16.89it/s]
# numpy-1.15.4         | 34 KB     | : 100% 1.0/1 [00:00<00:00, 11.91it/s]
# xorg-kbproto-1.0.7   | 26 KB     | : 100% 1.0/1 [00:00<00:00, 30.75it/s]
# xorg-libxau-1.0.9    | 13 KB     | : 100% 1.0/1 [00:00<00:00, 28.39it/s]
# ipython_genutils-0.2 | 21 KB     | : 100% 1.0/1 [00:00<00:00, 32.49it/s]
# traitlets-4.3.3      | 133 KB    | : 100% 1.0/1 [00:00<00:00, 14.01it/s]
# deepchem-gpu-2.1.0   | 1.9 MB    | : 100% 1.0/1 [00:00<00:00, 24.32s/it]
# idna-2.6             | 122 KB    | : 100% 1.0/1 [00:00<00:00, 17.32it/s]
# libuuid-2.32.1       | 26 KB     | : 100% 1.0/1 [00:00<00:00, 29.71it/s]
# pandocfilters-1.4.2  | 9 KB      | : 100% 1.0/1 [00:00<00:00, 34.29it/s]
# pillow-5.0.0         | 975 KB    | : 100% 1.0/1 [00:00<00:00,  4.39it/s]
# ipykernel-5.1.2      | 159 KB    | : 100% 1.0/1 [00:00<00:00, 13.43it/s]
# pixman-0.34.0        | 595 KB    | : 100% 1.0/1 [00:00<00:00,  7.89it/s]
# libprotobuf-3.9.2    | 4.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
# icu-58.2             | 22.6 MB   | : 100% 1.0/1 [00:03<00:00,  2.93s/it]
# wheel-0.33.6         | 35 KB     | : 100% 1.0/1 [00:00<00:00, 26.13it/s]
# mock-3.0.5           | 44 KB     | : 100% 1.0/1 [00:00<00:00, 22.46it/s]
# qtconsole-4.5.5      | 90 KB     | : 100% 1.0/1 [00:00<00:00, 17.96it/s]
# chardet-3.0.4        | 190 KB    | : 100% 1.0/1 [00:00<00:00, 11.85it/s]
# gettext-0.19.8.1     | 3.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.08it/s]
# mkl_random-1.0.2     | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  3.71it/s]
# simdna-0.4.2         | 627 KB    | : 100% 1.0/1 [00:01<00:00, 10.29s/it]
# terminado-0.8.2      | 23 KB     | : 100% 1.0/1 [00:00<00:00, 23.98it/s]
# mkl-2018.0.3         | 126.9 MB  | : 100% 1.0/1 [00:07<00:00,  7.99s/it]
# mistune-0.8.4        | 53 KB     | : 100% 1.0/1 [00:00<00:00,  3.67it/s]
# kiwisolver-1.1.0     | 86 KB     | : 100% 1.0/1 [00:00<00:00,  9.69it/s]
# glib-2.55.0          | 6.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.22s/it]
# matplotlib-2.2.2     | 4.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.75it/s]
# joblib-0.11          | 193 KB    | : 100% 1.0/1 [00:00<00:00,  3.80it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 11.60it/s]
# pip-19.2.3           | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
# gast-0.3.2           | 11 KB     | : 100% 1.0/1 [00:00<00:00, 32.62it/s]
# notebook-6.0.1       | 6.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.42s/it]
# tensorflow-gpu-base- | 68.1 MB   | : 100% 1.0/1 [00:08<00:00,  8.20s/it]
# c-ares-1.15.0        | 100 KB    | : 100% 1.0/1 [00:00<00:00, 14.24it/s]
# libtiff-4.0.9        | 566 KB    | : 100% 1.0/1 [00:00<00:00,  7.70it/s]
# entrypoints-0.3      | 12 KB     | : 100% 1.0/1 [00:00<00:00,  7.86it/s]
# sip-4.18.1           | 277 KB    | : 100% 1.0/1 [00:00<00:00, 10.60it/s]
# pyparsing-2.4.2      | 57 KB     | : 100% 1.0/1 [00:00<00:00, 24.50it/s]
# libiconv-1.15        | 2.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
# cudatoolkit-9.0      | 237.0 MB  | : 100% 1.0/1 [00:07<00:00,  8.00s/it]
# pyopenssl-19.0.0     | 81 KB     | : 100% 1.0/1 [00:00<00:00, 11.26it/s]
# bleach-1.5.0         | 23 KB     | : 100% 1.0/1 [00:00<00:00, 27.90it/s]
# cryptography-2.5     | 645 KB    | : 100% 1.0/1 [00:00<00:00,  4.54it/s]
# rdkit-2017.09.1      | 19.7 MB   | : 100% 1.0/1 [00:05<00:00, 47.70s/it]
# nbformat-4.4.0       | 91 KB     | : 100% 1.0/1 [00:00<00:00, 17.35it/s]
# pyzmq-18.1.0         | 516 KB    | : 100% 1.0/1 [00:00<00:00,  6.07it/s]
# pickleshare-0.7.5    | 12 KB     | : 100% 1.0/1 [00:00<00:00, 26.69it/s]
# scikit-learn-0.19.1  | 3.9 MB    | : 100% 1.0/1 [00:00<00:00,  2.85it/s]
# qt-5.6.2             | 34.8 MB   | : 100% 1.0/1 [00:01<00:00,  1.97s/it]
# pandas-0.22.0        | 26.1 MB   | : 100% 1.0/1 [00:04<00:00,  5.00s/it]
# python-dateutil-2.8. | 219 KB    | : 100% 1.0/1 [00:00<00:00, 15.18it/s]
# defusedxml-0.6.0     | 22 KB     | : 100% 1.0/1 [00:00<00:00, 24.05it/s]
# cupti-9.0.176        | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  8.98it/s]
# pytz-2019.2          | 228 KB    | : 100% 1.0/1 [00:00<00:00,  6.62it/s]
# pycparser-2.19       | 173 KB    | : 100% 1.0/1 [00:00<00:00, 11.47it/s]
# testpath-0.4.2       | 85 KB     | : 100% 1.0/1 [00:00<00:00, 21.38it/s]
# fontconfig-2.13.0    | 284 KB    | : 100% 1.0/1 [00:00<00:00, 10.44it/s]
# numpy-base-1.15.4    | 3.4 MB    | : 100% 1.0/1 [00:00<00:00,  3.66it/s]
# jpeg-9c              | 251 KB    | : 100% 1.0/1 [00:00<00:00, 11.34it/s]
# blosc-1.17.0         | 862 KB    | : 100% 1.0/1 [00:00<00:00,  5.97it/s]
# pthread-stubs-0.4    | 5 KB      | : 100% 1.0/1 [00:00<00:00, 26.96it/s]
# certifi-2019.9.11    | 147 KB    | : 100% 1.0/1 [00:00<00:00, 12.14it/s]
# jupyter_core-4.4.0   | 44 KB     | : 100% 1.0/1 [00:00<00:00, 22.89it/s]
# pdbfixer-1.4         | 187 KB    | : 100% 1.0/1 [00:00<00:00,  4.18s/it]
# ptyprocess-0.6.0     | 15 KB     | : 100% 1.0/1 [00:00<00:00,  3.33it/s]
# absl-py-0.8.0        | 157 KB    | : 100% 1.0/1 [00:00<00:00, 14.03it/s]
# expat-2.2.5          | 191 KB    | : 100% 1.0/1 [00:00<00:00, 14.74it/s]
# cairo-1.14.12        | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  3.06it/s]
# backcall-0.1.0       | 13 KB     | : 100% 1.0/1 [00:00<00:00, 17.06it/s]
# send2trash-1.5.0     | 12 KB     | : 100% 1.0/1 [00:00<00:00, 24.83it/s]
# boost-1.63.0         | 11.8 MB   | : 100% 1.0/1 [00:05<00:00,  5.84s/it]
# xgboost-0.6a2        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  6.08s/it]
# zeromq-4.3.2         | 668 KB    | : 100% 1.0/1 [00:00<00:00, 17.74s/it]
# asn1crypto-1.0.0     | 157 KB    | : 100% 1.0/1 [00:00<00:00, 10.66it/s]
# jupyter_client-5.3.3 | 132 KB    | : 100% 1.0/1 [00:00<00:00, 13.68it/s]
# jupyter_console-6.0. | 19 KB     | : 100% 1.0/1 [00:00<00:00, 30.47it/s]
# openmm-7.4.0         | 11.9 MB   | : 100% 1.0/1 [00:03<00:00,  3.98s/it]
# pycosat-0.6.3        | 104 KB    | : 100% 1.0/1 [00:00<00:00, 16.85it/s]
# libxcb-1.13          | 396 KB    | : 100% 1.0/1 [00:00<00:00,  6.90it/s]
# cffi-1.12.3          | 218 KB    | : 100% 1.0/1 [00:00<00:00, 12.02it/s]
# jinja2-2.10.1        | 91 KB     | : 100% 1.0/1 [00:00<00:00, 17.06it/s]
# ipython-7.8.0        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.26it/s]
# pyqt-5.6.0           | 5.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.42s/it]
# hdf5-1.10.5          | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.84it/s]
# markdown-3.1.1       | 60 KB     | : 100% 1.0/1 [00:00<00:00, 19.25it/s]
# setuptools-41.2.0    | 634 KB    | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
# wcwidth-0.1.7        | 17 KB     | : 100% 1.0/1 [00:00<00:00, 26.07it/s]
# werkzeug-0.16.0      | 259 KB    | : 100% 1.0/1 [00:00<00:00, 10.28it/s]
# pexpect-4.7.0        | 78 KB     | : 100% 1.0/1 [00:00<00:00, 16.20it/s]
# gst-plugins-base-1.1 | 4.9 MB    | : 100% 1.0/1 [00:00<00:00,  1.26it/s]
# freetype-2.8.1       | 789 KB    | : 100% 1.0/1 [00:00<00:00,  5.28it/s]
# conda-4.7.12         | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.55it/s]
# numexpr-2.7.0        | 196 KB    | : 100% 1.0/1 [00:00<00:00, 14.38it/s]
# mkl_fft-1.0.10       | 650 KB    | : 100% 1.0/1 [00:00<00:00,  6.52it/s]
# fftw3f-3.3.4         | 1.2 MB    | : 100% 1.0/1 [00:01<00:00, 13.67s/it]
# ruamel_yaml-0.15.71  | 257 KB    | : 100% 1.0/1 [00:00<00:00, 10.88it/s]
# done
# done
# / b'Enabling notebook extension jupyter-js-widgets/extension...\nPaths used for configuration of notebook: \n    \t/usr/local/etc/jupyter/nbconfig/notebook.d/plotlywidget.json\n    \t/usr/local/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json\n    \t/usr/local/etc/jupyter/nbconfig/notebook.json\nPaths used for configuration of notebook: \n    \t/usr/local/etc/jupyter/nbconfig/notebook.d/plotlywidget.json\n    \t/usr/local/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json\n      - Validating: \x1bOK\x1b\nPaths used for configuration of notebook: \n    \t/usr/local/etc/jupyter/nbconfig/notebook.d/plotlywidget.json\n    \t/usr/local/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json\n    \t/usr/local/etc/jupyter/nbconfig/notebook.json\n'
# done

# %%
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages/')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import numpy as np
import tensorflow as tf
import deepchem as dc
from deepchem.models.tensorgraph.models.graph_models import GraphConvModel

# %%
# Load Tox21 dataset
tox21_tasks, tox21_datasets, transformers = dc.molnet.load_tox21(featurizer='GraphConv')
train_dataset, valid_dataset, test_dataset = tox21_datasets
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from /tmp/tox21.csv.gz
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# Featurizing sample 3000
# Featurizing sample 4000
# Featurizing sample 5000
# Featurizing sample 6000
# Featurizing sample 7000
# TIMING: featurizing shard 0 took 25.970 s
# TIMING: dataset construction took 29.084 s
# Loading dataset from disk.
# TIMING: dataset construction took 3.909 s
# Loading dataset from disk.
# TIMING: dataset construction took 3.428 s
# Loading dataset from disk.
# TIMING: dataset construction took 1.827 s
# Loading dataset from disk.
# TIMING: dataset construction took 1.513 s
# Loading dataset from disk.

# %%
tox21_tasks
# Out:
# ['NR-AR',
#  'NR-AR-LBD',
#  'NR-AhR',
#  'NR-Aromatase',
#  'NR-ER',
#  'NR-ER-LBD',
#  'NR-PPAR-gamma',
#  'SR-ARE',
#  'SR-ATAD5',
#  'SR-HSE',
#  'SR-MMP',
#  'SR-p53']

# %%
nn = train_dataset.ids

# %%
nn.view()
# Out:
# array(['CCOc1ccc2nc(S(N)(=O)=O)sc2c1', 'CCN1C(=O)NC(c2ccccc2)C1=O',
#        'CC[C@]1(O)CC[C@H]2[C@@H]3CCC4=CCCC[C@@H]4[C@H]3CC[C@@]21C', ...,
#        'C[C@@H](N)C(=O)O', 'CCOP(=S)(OCC)SC(CCl)N1C(=O)c2ccccc2C1=O',
#        'CCOP(=O)(OCC)Oc1cc(C)nc(C(C)C)n1'], dtype=object)

# %%
model = GraphConvModel(
    len(tox21_tasks), batch_size=50, mode='classification')
# Set nb_epoch=10 for better results.
model.fit(train_dataset, nb_epoch=10)
# Out:
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb578893940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb578893940>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb578893940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb578893940>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cf329940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cf329940>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cf329940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cf329940>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cc730ef0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cc730ef0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cc730ef0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cc730ef0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cc730ef0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cc730ef0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cc730ef0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cc730ef0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cfa4a160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cfa4a160>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cfa4a160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cfa4a160>>: AssertionError: Bad argument number for Name: 3, expecting 4
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 392.83389597925645

# %%
metric = dc.metrics.Metric(
    dc.metrics.roc_auc_score, np.mean, mode="classification")

print("Evaluating model")
train_scores = model.evaluate(train_dataset, [metric], transformers)
print("Training ROC-AUC Score: %f" % train_scores["mean-roc_auc_score"])
valid_scores = model.evaluate(valid_dataset, [metric], transformers)
print("Validation ROC-AUC Score: %f" % valid_scores["mean-roc_auc_score"])
# Out:
# Evaluating model
# computed_metrics: [0.9038373912317179, 0.9604510376525369, 0.909439975238759, 0.9245169070584794, 0.7903611231165338, 0.9084788464135202, 0.956035961093747, 0.840473249479049, 0.9301439627513346, 0.8737605606925385, 0.9104812195052338, 0.910130335067405]
# Training ROC-AUC Score: 0.901509
# computed_metrics: [0.8587542670558551, 0.8333333333333334, 0.8629681882310107, 0.8191408235892221, 0.69075, 0.7548186610022816, 0.7655763239875388, 0.8305972427722585, 0.8254768071579939, 0.7691702624955052, 0.8797815516539318, 0.8459086993970715]
# Validation ROC-AUC Score: 0.811356

# %%
from deepchem.models.tensorgraph.tensor_graph import TensorGraph

tg = TensorGraph(use_queue=False)

# %%
from deepchem.models.tensorgraph.layers import Feature

atom_features = Feature(shape=(None, 75))
degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
membership = Feature(shape=(None,), dtype=tf.int32)

deg_adjs = []
for i in range(0, 10 + 1):
    deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
    deg_adjs.append(deg_adj)

# %%
from deepchem.models.tensorgraph.layers import Dense, GraphConv, BatchNorm
from deepchem.models.tensorgraph.layers import GraphPool, GraphGather

batch_size = 50

gc1 = GraphConv(
    64,
    activation_fn=tf.nn.relu,
    in_layers=[atom_features, degree_slice, membership] + deg_adjs)
batch_norm1 = BatchNorm(in_layers=[gc1])
gp1 = GraphPool(in_layers=[batch_norm1, degree_slice, membership] + deg_adjs)
gc2 = GraphConv(
    64,
    activation_fn=tf.nn.relu,
    in_layers=[gp1, degree_slice, membership] + deg_adjs)
batch_norm2 = BatchNorm(in_layers=[gc2])
gp2 = GraphPool(in_layers=[batch_norm2, degree_slice, membership] + deg_adjs)
dense = Dense(out_channels=128, activation_fn=tf.nn.relu, in_layers=[gp2])
batch_norm3 = BatchNorm(in_layers=[dense])
readout = GraphGather(
    batch_size=batch_size,
    activation_fn=tf.nn.tanh,
    in_layers=[batch_norm3, degree_slice, membership] + deg_adjs)

# %%
from deepchem.models.tensorgraph.layers import Dense, SoftMax, \
    SoftMaxCrossEntropy, WeightedError, Stack
from deepchem.models.tensorgraph.layers import Label, Weights

costs = []
labels = []
for task in range(len(tox21_tasks)):
    classification = Dense(
        out_channels=2, activation_fn=None, in_layers=[readout])

    softmax = SoftMax(in_layers=[classification])
    tg.add_output(softmax)

    label = Label(shape=(None, 2))
    labels.append(label)
    cost = SoftMaxCrossEntropy(in_layers=[label, classification])
    costs.append(cost)
all_cost = Stack(in_layers=costs, axis=1)
weights = Weights(shape=(None, len(tox21_tasks)))
loss = WeightedError(in_layers=[all_cost, weights])
tg.set_loss(loss)

# %%
from deepchem.metrics import to_one_hot
from deepchem.feat.mol_graphs import ConvMol

def data_generator(dataset, epochs=1, predict=False, pad_batches=True):
  for epoch in range(epochs):
    if not predict:
        print('Starting epoch %i' % epoch)
    for ind, (X_b, y_b, w_b, ids_b) in enumerate(
        dataset.iterbatches(
            batch_size, pad_batches=pad_batches, deterministic=True)):
      d = {}
      for index, label in enumerate(labels):
        d[label] = to_one_hot(y_b[:, index])
      d[weights] = w_b
      multiConvMol = ConvMol.agglomerate_mols(X_b)
      d[atom_features] = multiConvMol.get_atom_features()
      d[degree_slice] = multiConvMol.deg_slice
      d[membership] = multiConvMol.membership
      for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
        d[deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
      yield d

# %%
# Epochs set to 1 to render tutorials online.
# Set epochs=10 for better results.
tg.fit_generator(data_generator(train_dataset, epochs=1))
# Out:
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cc47e240>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cc47e240>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cc47e240>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5cc47e240>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5d07fc9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5d07fc9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5d07fc9e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb5d07fc9e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb574f97ba8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb574f97ba8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb574f97ba8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb574f97ba8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb574f97ba8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb574f97ba8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb574f97ba8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BatchNormalization.call of <tensorflow.python.layers.normalization.BatchNormalization object at 0x7fb574f97ba8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572135550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572135550>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572135550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572135550>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5721352e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5721352e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5721352e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5721352e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572135cf8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572135cf8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572135cf8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572135cf8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572ed2128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572ed2128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572ed2128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572ed2128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cf678eb8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cf678eb8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cf678eb8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5cf678eb8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572ed2128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572ed2128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572ed2128>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb572ed2128>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5ca3062e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5ca3062e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5ca3062e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5ca3062e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5787eb470>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5787eb470>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5787eb470>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5787eb470>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb57a3edf28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb57a3edf28>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb57a3edf28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb57a3edf28>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5721352e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5721352e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5721352e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5721352e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5c9ba74a8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5c9ba74a8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5c9ba74a8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb5c9ba74a8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb571c6d710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb571c6d710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb571c6d710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb571c6d710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# 592.2948114304315

# %%
metric = dc.metrics.Metric(
    dc.metrics.roc_auc_score, np.mean, mode="classification")

def reshape_y_pred(y_true, y_pred):
    """
    TensorGraph.Predict returns a list of arrays, one for each output
    We also have to remove the padding on the last batch
    Metrics taks results of shape (samples, n_task, prob_of_class)
    """
    n_samples = len(y_true)
    retval = np.stack(y_pred, axis=1)
    return retval[:n_samples]


print("Evaluating model")
train_predictions = tg.predict_on_generator(data_generator(train_dataset, predict=True))
train_predictions = reshape_y_pred(train_dataset.y, train_predictions)
train_scores = metric.compute_metric(train_dataset.y, train_predictions, train_dataset.w)
print("Training ROC-AUC Score: %f" % train_scores)

valid_predictions = tg.predict_on_generator(data_generator(valid_dataset, predict=True))
valid_predictions = reshape_y_pred(valid_dataset.y, valid_predictions)
valid_scores = metric.compute_metric(valid_dataset.y, valid_predictions, valid_dataset.w)
print("Valid ROC-AUC Score: %f" % valid_scores)
# Out:
# Evaluating model
# computed_metrics: [0.8016323072746852, 0.8376565510597302, 0.8354434571112075, 0.7398847189546731, 0.6836909102326836, 0.7371436795087734, 0.7626851829417671, 0.6702208497568896, 0.7615497310050597, 0.6880034002394045, 0.7972915565913944, 0.7208786429490408]
# Training ROC-AUC Score: 0.753007
# computed_metrics: [0.7317567901845348, 0.7253637566137566, 0.8018022118053976, 0.7282663955261819, 0.6404318181818182, 0.6137990716702069, 0.5941502249913465, 0.6580708800112731, 0.6876854250058866, 0.5630843221862639, 0.73534695441807, 0.6347975882859604]
# Valid ROC-AUC Score: 0.676213
